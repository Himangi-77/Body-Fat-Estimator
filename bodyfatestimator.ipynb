# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/bodyfat.csv')
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
def plotdistplots(col):
  plt.figure(figsize=(12,5))
  sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
  sn.distplot(df[col],color='red', hist=False, label=col)
  plt.legend()
  plt.show()

cols = list(df.columns)
for i in cols:
  print(f"Distribution plots for {i} feature is shown")
  plotdistplots(i)
  print("-"*100)
# Out:
# Distribution plots for Density feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for BodyFat feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Age feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Weight feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Height feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Neck feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Chest feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Abdomen feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Hip feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Thigh feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Knee feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Ankle feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Biceps feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Forearm feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Wrist feature is shown
# <ipython-input-4-88c1062af037>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# <ipython-input-4-88c1062af037>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------

# %%
import scipy.stats as stats

def drawplots(df,col):
  plt.figure(figsize=(12,5))
  plt.subplot(1,3,1)
  plt.hist(df[col],color='magenta')

  plt.subplot(1,3,2)
  stats.probplot(df[col],dist='norm',plot=plt)

  plt.subplot(1,3,3)
  sn.boxplot(df[col],color='magenta')

  plt.show()

cols = list(df.columns)
for i in range(len(cols)):
  print(f"Distribution plots for the feature {cols[i]} are shown")

  drawplots(df,cols[i])

  print("-"*100)
# Out:
# Distribution plots for the feature Density are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature BodyFat are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Age are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Weight are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Height are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Neck are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Chest are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Abdomen are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Hip are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Thigh are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Knee are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Ankle are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Biceps are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Forearm are shown
# ----------------------------------------------------------------------------------------------------
# Distribution plots for the feature Wrist are shown
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Outlier Detection**

# %%
upperlimit = []
lowerlimit = []
for i in df.columns:
  upperlimit.append(df[i].mean()+(df[i].std())*4)
  lowerlimit.append(df[i].mean()-(df[i].std())*4)

# %%
cols = list(df.columns)
j = 0
for i in range(len(cols)):
  temp = df.loc[(df[cols[i]] > upperlimit[j]) & (df[cols[i]] < lowerlimit[j])]
  j += 1

# %%
temp
# Out:
# Empty DataFrame
# Columns: [Density, BodyFat, Age, Weight, Height, Neck, Chest, Abdomen, Hip, Thigh, Knee, Ankle, Biceps, Forearm, Wrist]
# Index: []

# %% [markdown]
# **Feature Selection**

# %%
data = df.copy()
test = data['BodyFat']
train = data.drop(['BodyFat'], axis=1)

# %%
from sklearn.ensemble import ExtraTreesRegressor

er = ExtraTreesRegressor()
er.fit(train,test)
# Out:
# ExtraTreesRegressor()

# %%
series = pd.Series(er.feature_importances_, index=train.columns)
series.nlargest(5).plot(kind='barh',color='green')
# Out:
# <Axes: >

# %% [markdown]
# **Feature Selection using Mutual Information Gain**

# %%
from sklearn.feature_selection import mutual_info_regression
mr = mutual_info_regression(train,test)

# %%
plotdata = pd.Series(mr,index=train.columns)
plotdata.nlargest(5).plot(kind='barh',color='green')
# Out:
# <Axes: >

# %% [markdown]
# **Correlation Removal**

# %%
plt.figure(figsize=(15,7))
sn.heatmap(df.corr(),annot=True,cmap='plasma')
# Out:
# <Axes: >

# %%
def correlation(df,threshold):

  colcor = set()

  cormat = df.corr()

  for i in range(len(cormat)):

    for j in range(i):

      if abs(cormat.iloc[i][j])>threshold:
        colname = cormat.columns[i]
        colcor.add(colname)

  return colcor

ans = correlation(train,0.85)

ans
# Out:
# {'Abdomen', 'Chest', 'Hip', 'Knee', 'Thigh'}

# %% [markdown]
# If the variance is between 70-80% it means the feature will contribute alot to the independent feature

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
temp = data[list(data.columns)]
info = pd.DataFrame()
info['VIF'] = [variance_inflation_factor(temp.values,i) for i in range(temp.shape[1])]
info['Column'] = temp.columns
info.sort_values('VIF', ascending=False)
# Out:
#             VIF   Column
# 0   3695.622377  Density
# 8   2933.636131      Hip
# 6   1374.457425    Chest
# 14  1349.973920    Wrist
# 7   1332.624257  Abdomen
# 3   1238.097164   Weight
# 10  1187.890413     Knee
# 5   1081.965633     Neck
# 9   1017.257501    Thigh
# 4    613.410514   Height
# 13   454.571766  Forearm
# 12   419.391664   Biceps
# 11   356.293529    Ankle
# 1     33.845429  BodyFat
# 2     31.376101      Age

# %%
cols1 = list(series.nlargest(5).index)
cols2 = list(plotdata.nlargest(5).index)

cols1, cols2
# Out:
# (['Density', 'Abdomen', 'Chest', 'Hip', 'Weight'],
#  ['Density', 'Abdomen', 'Chest', 'Hip', 'Weight'])

# %%
totrain = train[cols1]
totrain.head()
# Out:
#    Density  Abdomen  Chest    Hip  Weight
# 0   1.0708     85.2   93.1   94.5  154.25
# 1   1.0853     83.0   93.6   98.7  173.25
# 2   1.0414     87.9   95.8   99.2  154.00
# 3   1.0751     86.4  101.8  101.2  184.75
# 4   1.0340    100.0   97.3  101.9  184.25

# %% [markdown]
# **Model Building**

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
X_train, X_test, y_train, y_test = train_test_split(totrain, test, test_size=0.2)
X_train.shape, X_test.shape
# Out:
# ((201, 5), (51, 5))

# %%
reg = DecisionTreeRegressor()
reg.fit(X_train,y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(reg,filled=True)
# Out:
# [Text(0.4892105899419729, 0.9545454545454546, 'x[0] <= 1.056\nsquared_error = 74.36\nsamples = 201\nvalue = 18.948'),
#  Text(0.19771518375241778, 0.8636363636363636, 'x[0] <= 1.036\nsquared_error = 26.994\nsamples = 99\nvalue = 26.201'),
#  Text(0.05222437137330754, 0.7727272727272727, 'x[0] <= 1.016\nsquared_error = 15.469\nsamples = 32\nvalue = 32.341'),
#  Text(0.01160541586073501, 0.6818181818181818, 'x[2] <= 119.15\nsquared_error = 16.347\nsamples = 3\nvalue = 41.9'),
#  Text(0.007736943907156673, 0.5909090909090909, 'x[4] <= 218.0\nsquared_error = 1.0\nsamples = 2\nvalue = 39.1'),
#  Text(0.0038684719535783366, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 40.1'),
#  Text(0.01160541586073501, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 38.1'),
#  Text(0.015473887814313346, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 47.5'),
#  Text(0.09284332688588008, 0.6818181818181818, 'x[0] <= 1.029\nsquared_error = 4.947\nsamples = 29\nvalue = 31.352'),
#  Text(0.04642166344294004, 0.5909090909090909, 'x[0] <= 1.024\nsquared_error = 1.503\nsamples = 15\nvalue = 33.22'),
#  Text(0.019342359767891684, 0.5, 'x[2] <= 117.25\nsquared_error = 0.276\nsamples = 6\nvalue = 34.567'),
#  Text(0.009671179883945842, 0.4090909090909091, 'x[3] <= 108.2\nsquared_error = 0.122\nsamples = 2\nvalue = 33.95'),
#  Text(0.005802707930367505, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 33.6'),
#  Text(0.013539651837524178, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 34.3'),
#  Text(0.029013539651837523, 0.4090909090909091, 'x[0] <= 1.021\nsquared_error = 0.067\nsamples = 4\nvalue = 34.875'),
#  Text(0.02127659574468085, 0.3181818181818182, 'x[1] <= 133.05\nsquared_error = 0.01\nsamples = 2\nvalue = 35.1'),
#  Text(0.017408123791102514, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 35.0'),
#  Text(0.025145067698259187, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 35.2'),
#  Text(0.0367504835589942, 0.3181818181818182, 'x[2] <= 124.95\nsquared_error = 0.023\nsamples = 2\nvalue = 34.65'),
#  Text(0.03288201160541586, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 34.8'),
#  Text(0.04061895551257253, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 34.5'),
#  Text(0.0735009671179884, 0.5, 'x[0] <= 1.027\nsquared_error = 0.306\nsamples = 9\nvalue = 32.322'),
#  Text(0.059961315280464215, 0.4090909090909091, 'x[1] <= 104.9\nsquared_error = 0.045\nsamples = 6\nvalue = 32.683'),
#  Text(0.05222437137330754, 0.3181818181818182, 'x[0] <= 1.025\nsquared_error = 0.002\nsamples = 3\nvalue = 32.867'),
#  Text(0.048355899419729204, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 32.9'),
#  Text(0.05609284332688588, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.8'),
#  Text(0.06769825918762089, 0.3181818181818182, 'x[2] <= 110.05\nsquared_error = 0.02\nsamples = 3\nvalue = 32.5'),
#  Text(0.06382978723404255, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.3'),
#  Text(0.07156673114119923, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 32.6'),
#  Text(0.08704061895551257, 0.4090909090909091, 'x[3] <= 102.1\nsquared_error = 0.047\nsamples = 3\nvalue = 31.6'),
#  Text(0.08317214700193423, 0.3181818181818182, 'x[0] <= 1.028\nsquared_error = 0.003\nsamples = 2\nvalue = 31.45'),
#  Text(0.07930367504835589, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.08704061895551257, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 31.4'),
#  Text(0.09090909090909091, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 31.9'),
#  Text(0.13926499032882012, 0.5909090909090909, 'x[0] <= 1.032\nsquared_error = 0.89\nsamples = 14\nvalue = 29.35'),
#  Text(0.11218568665377177, 0.5, 'x[0] <= 1.03\nsquared_error = 0.299\nsamples = 6\nvalue = 30.25'),
#  Text(0.10251450676982592, 0.4090909090909091, 'x[0] <= 1.029\nsquared_error = 0.062\nsamples = 2\nvalue = 30.95'),
#  Text(0.09864603481624758, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 31.2'),
#  Text(0.10638297872340426, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.1218568665377176, 0.4090909090909091, 'x[0] <= 1.031\nsquared_error = 0.05\nsamples = 4\nvalue = 29.9'),
#  Text(0.11411992263056092, 0.3181818181818182, 'x[1] <= 103.95\nsquared_error = 0.01\nsamples = 2\nvalue = 30.1'),
#  Text(0.1102514506769826, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 30.0'),
#  Text(0.11798839458413926, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 30.2'),
#  Text(0.12959381044487428, 0.3181818181818182, 'x[0] <= 1.032\nsquared_error = 0.01\nsamples = 2\nvalue = 29.7'),
#  Text(0.12572533849129594, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.13346228239845262, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.16634429400386846, 0.5, 'x[0] <= 1.034\nsquared_error = 0.269\nsamples = 8\nvalue = 28.675'),
#  Text(0.1528046421663443, 0.4090909090909091, 'x[0] <= 1.033\nsquared_error = 0.086\nsamples = 5\nvalue = 29.02'),
#  Text(0.1450676982591876, 0.3181818181818182, 'x[4] <= 187.25\nsquared_error = 0.002\nsamples = 2\nvalue = 29.35'),
#  Text(0.14119922630560927, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 29.3'),
#  Text(0.14893617021276595, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 29.4'),
#  Text(0.16054158607350097, 0.3181818181818182, 'x[1] <= 104.6\nsquared_error = 0.02\nsamples = 3\nvalue = 28.8'),
#  Text(0.15667311411992263, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 28.7'),
#  Text(0.1644100580270793, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 29.0'),
#  Text(0.17988394584139264, 0.4090909090909091, 'x[3] <= 104.45\nsquared_error = 0.047\nsamples = 3\nvalue = 28.1'),
#  Text(0.1760154738878143, 0.3181818181818182, 'x[3] <= 103.55\nsquared_error = 0.002\nsamples = 2\nvalue = 27.95'),
#  Text(0.172147001934236, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 28.0'),
#  Text(0.17988394584139264, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.18375241779497098, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.343205996131528, 0.7727272727272727, 'x[0] <= 1.047\nsquared_error = 5.896\nsamples = 67\nvalue = 23.269'),
#  Text(0.2674081237911025, 0.6818181818181818, 'x[0] <= 1.041\nsquared_error = 1.461\nsamples = 34\nvalue = 25.359'),
#  Text(0.22437137330754353, 0.5909090909090909, 'x[0] <= 1.039\nsquared_error = 0.29\nsamples = 13\nvalue = 26.646'),
#  Text(0.20696324951644102, 0.5, 'x[0] <= 1.038\nsquared_error = 0.078\nsamples = 9\nvalue = 26.967'),
#  Text(0.195357833655706, 0.4090909090909091, 'x[4] <= 172.75\nsquared_error = 0.012\nsamples = 5\nvalue = 27.2'),
#  Text(0.19148936170212766, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.19922630560928434, 0.3181818181818182, 'x[4] <= 217.5\nsquared_error = 0.003\nsamples = 4\nvalue = 27.25'),
#  Text(0.195357833655706, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 27.2'),
#  Text(0.20309477756286268, 0.22727272727272727, 'x[4] <= 218.95\nsquared_error = 0.0\nsamples = 2\nvalue = 27.3'),
#  Text(0.19922630560928434, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.20696324951644102, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.218568665377176, 0.4090909090909091, 'x[4] <= 164.375\nsquared_error = 0.007\nsamples = 4\nvalue = 26.675'),
#  Text(0.21470019342359767, 0.3181818181818182, 'x[0] <= 1.038\nsquared_error = 0.003\nsamples = 2\nvalue = 26.75'),
#  Text(0.21083172147001933, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.8'),
#  Text(0.218568665377176, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.7'),
#  Text(0.22243713733075435, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 26.6'),
#  Text(0.24177949709864605, 0.5, 'x[0] <= 1.04\nsquared_error = 0.017\nsamples = 4\nvalue = 25.925'),
#  Text(0.23404255319148937, 0.4090909090909091, 'x[4] <= 173.875\nsquared_error = 0.002\nsamples = 2\nvalue = 26.05'),
#  Text(0.23017408123791103, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 26.1'),
#  Text(0.2379110251450677, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.2495164410058027, 0.4090909090909091, 'x[2] <= 100.35\nsquared_error = 0.0\nsamples = 2\nvalue = 25.8'),
#  Text(0.24564796905222436, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 25.8'),
#  Text(0.25338491295938104, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 25.8'),
#  Text(0.3104448742746615, 0.5909090909090909, 'x[0] <= 1.044\nsquared_error = 0.525\nsamples = 21\nvalue = 24.562'),
#  Text(0.2862669245647969, 0.5, 'x[0] <= 1.042\nsquared_error = 0.134\nsamples = 15\nvalue = 24.96'),
#  Text(0.2688588007736944, 0.4090909090909091, 'x[0] <= 1.041\nsquared_error = 0.01\nsamples = 7\nvalue = 25.314'),
#  Text(0.2611218568665377, 0.3181818181818182, 'x[3] <= 100.05\nsquared_error = 0.002\nsamples = 2\nvalue = 25.45'),
#  Text(0.2572533849129594, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 25.4'),
#  Text(0.26499032882011603, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 25.5'),
#  Text(0.2765957446808511, 0.3181818181818182, 'x[0] <= 1.041\nsquared_error = 0.002\nsamples = 5\nvalue = 25.26'),
#  Text(0.2727272727272727, 0.22727272727272727, 'x[4] <= 169.625\nsquared_error = 0.0\nsamples = 3\nvalue = 25.3'),
#  Text(0.2688588007736944, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.2765957446808511, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 25.3'),
#  Text(0.2804642166344294, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 25.2'),
#  Text(0.3036750483558994, 0.4090909090909091, 'x[0] <= 1.043\nsquared_error = 0.038\nsamples = 8\nvalue = 24.65'),
#  Text(0.29206963249516443, 0.3181818181818182, 'x[1] <= 97.85\nsquared_error = 0.007\nsamples = 4\nvalue = 24.825'),
#  Text(0.28820116054158607, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 24.9'),
#  Text(0.29593810444874274, 0.22727272727272727, 'x[1] <= 101.95\nsquared_error = 0.002\nsamples = 2\nvalue = 24.75'),
#  Text(0.29206963249516443, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.29980657640232106, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.3152804642166344, 0.3181818181818182, 'x[0] <= 1.043\nsquared_error = 0.007\nsamples = 4\nvalue = 24.475'),
#  Text(0.3114119922630561, 0.22727272727272727, 'x[1] <= 99.15\nsquared_error = 0.003\nsamples = 2\nvalue = 24.55'),
#  Text(0.30754352030947774, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(0.3152804642166344, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.3191489361702128, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 24.4'),
#  Text(0.3346228239845261, 0.5, 'x[0] <= 1.044\nsquared_error = 0.116\nsamples = 6\nvalue = 23.567'),
#  Text(0.3307543520309478, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 24.2'),
#  Text(0.33849129593810445, 0.4090909090909091, 'x[4] <= 168.875\nsquared_error = 0.042\nsamples = 5\nvalue = 23.44'),
#  Text(0.3307543520309478, 0.3181818181818182, 'x[0] <= 1.046\nsquared_error = 0.01\nsamples = 2\nvalue = 23.2'),
#  Text(0.32688588007736946, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.3346228239845261, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.34622823984526113, 0.3181818181818182, 'x[2] <= 103.65\nsquared_error = 0.0\nsamples = 3\nvalue = 23.6'),
#  Text(0.34235976789168276, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.35009671179883944, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 23.6'),
#  Text(0.4190038684719536, 0.6818181818181818, 'x[0] <= 1.05\nsquared_error = 1.326\nsamples = 33\nvalue = 21.115'),
#  Text(0.38007736943907156, 0.5909090909090909, 'x[0] <= 1.049\nsquared_error = 0.202\nsamples = 14\nvalue = 22.257'),
#  Text(0.36750483558994196, 0.5, 'x[0] <= 1.047\nsquared_error = 0.084\nsamples = 11\nvalue = 22.445'),
#  Text(0.3578336557059961, 0.4090909090909091, 'x[2] <= 94.8\nsquared_error = 0.002\nsamples = 3\nvalue = 22.867'),
#  Text(0.3539651837524178, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.3617021276595745, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 22.9'),
#  Text(0.3771760154738878, 0.4090909090909091, 'x[1] <= 93.35\nsquared_error = 0.024\nsamples = 8\nvalue = 22.288'),
#  Text(0.3694390715667311, 0.3181818181818182, 'x[0] <= 1.048\nsquared_error = 0.002\nsamples = 3\nvalue = 22.467'),
#  Text(0.3655705996131528, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 22.5'),
#  Text(0.3733075435203095, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.4'),
#  Text(0.3849129593810445, 0.3181818181818182, 'x[2] <= 101.65\nsquared_error = 0.006\nsamples = 5\nvalue = 22.18'),
#  Text(0.38104448742746616, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 22.1'),
#  Text(0.38878143133462284, 0.22727272727272727, 'x[1] <= 95.25\nsquared_error = 0.002\nsamples = 3\nvalue = 22.233'),
#  Text(0.3849129593810445, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 22.2'),
#  Text(0.39264990328820115, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.39264990328820115, 0.5, 'x[0] <= 1.05\nsquared_error = 0.029\nsamples = 3\nvalue = 21.567'),
#  Text(0.38878143133462284, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 21.8'),
#  Text(0.3965183752417795, 0.4090909090909091, 'x[0] <= 1.05\nsquared_error = 0.002\nsamples = 2\nvalue = 21.45'),
#  Text(0.39264990328820115, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 21.5'),
#  Text(0.40038684719535783, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.45793036750483557, 0.5909090909090909, 'x[0] <= 1.053\nsquared_error = 0.485\nsamples = 19\nvalue = 20.274'),
#  Text(0.43617021276595747, 0.5, 'x[0] <= 1.052\nsquared_error = 0.104\nsamples = 11\nvalue = 20.791'),
#  Text(0.42166344294003866, 0.4090909090909091, 'x[0] <= 1.051\nsquared_error = 0.04\nsamples = 7\nvalue = 21.0'),
#  Text(0.4081237911025145, 0.3181818181818182, 'x[4] <= 186.625\nsquared_error = 0.036\nsamples = 3\nvalue = 21.167'),
#  Text(0.40425531914893614, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.3'),
#  Text(0.4119922630560928, 0.22727272727272727, 'x[1] <= 97.45\nsquared_error = 0.04\nsamples = 2\nvalue = 21.1'),
#  Text(0.4081237911025145, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.4158607350096712, 0.13636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 21.3'),
#  Text(0.43520309477756286, 0.3181818181818182, 'x[0] <= 1.051\nsquared_error = 0.007\nsamples = 4\nvalue = 20.875'),
#  Text(0.4274661508704062, 0.22727272727272727, 'x[4] <= 181.5\nsquared_error = 0.002\nsamples = 2\nvalue = 20.95'),
#  Text(0.42359767891682787, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.43133462282398455, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.44294003868471954, 0.22727272727272727, 'x[2] <= 102.95\nsquared_error = 0.0\nsamples = 2\nvalue = 20.8'),
#  Text(0.43907156673114117, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.44680851063829785, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.4506769825918762, 0.4090909090909091, 'x[4] <= 206.375\nsquared_error = 0.007\nsamples = 4\nvalue = 20.425'),
#  Text(0.44680851063829785, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 20.5'),
#  Text(0.45454545454545453, 0.3181818181818182, 'x[4] <= 217.625\nsquared_error = 0.002\nsamples = 2\nvalue = 20.35'),
#  Text(0.4506769825918762, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.4'),
#  Text(0.4584139264990329, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.4796905222437137, 0.5, 'x[0] <= 1.054\nsquared_error = 0.135\nsamples = 8\nvalue = 19.562'),
#  Text(0.4661508704061896, 0.4090909090909091, 'x[4] <= 171.75\nsquared_error = 0.036\nsamples = 3\nvalue = 19.967'),
#  Text(0.4622823984526112, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 19.7'),
#  Text(0.4700193423597679, 0.3181818181818182, 'x[0] <= 1.053\nsquared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.4661508704061896, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.4738878143133462, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.4932301740812379, 0.4090909090909091, 'x[0] <= 1.055\nsquared_error = 0.038\nsamples = 5\nvalue = 19.32'),
#  Text(0.48549323017408125, 0.3181818181818182, 'x[2] <= 103.3\nsquared_error = 0.002\nsamples = 2\nvalue = 19.55'),
#  Text(0.4816247582205029, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.5'),
#  Text(0.48936170212765956, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.5009671179883946, 0.3181818181818182, 'x[0] <= 1.055\nsquared_error = 0.002\nsamples = 3\nvalue = 19.167'),
#  Text(0.49709864603481624, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 19.2'),
#  Text(0.504835589941973, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.1'),
#  Text(0.780705996131528, 0.8636363636363636, 'x[0] <= 1.072\nsquared_error = 19.724\nsamples = 102\nvalue = 11.909'),
#  Text(0.6593326885880078, 0.7727272727272727, 'x[0] <= 1.067\nsquared_error = 4.785\nsamples = 55\nvalue = 15.285'),
#  Text(0.6029980657640233, 0.6818181818181818, 'x[0] <= 1.062\nsquared_error = 1.89\nsamples = 35\nvalue = 16.674'),
#  Text(0.5638297872340425, 0.5909090909090909, 'x[0] <= 1.059\nsquared_error = 0.547\nsamples = 22\nvalue = 17.5'),
#  Text(0.539651837524178, 0.5, 'x[0] <= 1.057\nsquared_error = 0.114\nsamples = 10\nvalue = 18.22'),
#  Text(0.5241779497098646, 0.4090909090909091, 'x[0] <= 1.056\nsquared_error = 0.044\nsamples = 5\nvalue = 18.5'),
#  Text(0.5164410058027079, 0.3181818181818182, 'x[2] <= 103.2\nsquared_error = 0.003\nsamples = 2\nvalue = 18.75'),
#  Text(0.5125725338491296, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.8'),
#  Text(0.5203094777562862, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.5319148936170213, 0.3181818181818182, 'x[0] <= 1.057\nsquared_error = 0.002\nsamples = 3\nvalue = 18.333'),
#  Text(0.528046421663443, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.5357833655705996, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 18.3'),
#  Text(0.5551257253384912, 0.4090909090909091, 'x[3] <= 94.6\nsquared_error = 0.026\nsamples = 5\nvalue = 17.94'),
#  Text(0.5473887814313346, 0.3181818181818182, 'x[1] <= 84.1\nsquared_error = 0.002\nsamples = 2\nvalue = 17.75'),
#  Text(0.5435203094777563, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.7'),
#  Text(0.5512572533849129, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.562862669245648, 0.3181818181818182, 'x[4] <= 168.625\nsquared_error = 0.002\nsamples = 3\nvalue = 18.067'),
#  Text(0.5589941972920697, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.5667311411992263, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 18.1'),
#  Text(0.5880077369439072, 0.5, 'x[0] <= 1.06\nsquared_error = 0.117\nsamples = 12\nvalue = 16.9'),
#  Text(0.574468085106383, 0.4090909090909091, 'x[2] <= 94.0\nsquared_error = 0.007\nsamples = 3\nvalue = 17.4'),
#  Text(0.5705996131528046, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 17.3'),
#  Text(0.5783365570599613, 0.3181818181818182, 'x[0] <= 1.059\nsquared_error = 0.002\nsamples = 2\nvalue = 17.45'),
#  Text(0.574468085106383, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.5822050290135397, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.6015473887814313, 0.4090909090909091, 'x[0] <= 1.061\nsquared_error = 0.042\nsamples = 9\nvalue = 16.733'),
#  Text(0.5938104448742747, 0.3181818181818182, 'x[3] <= 98.45\nsquared_error = 0.002\nsamples = 4\nvalue = 16.95'),
#  Text(0.5899419729206963, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 17.0'),
#  Text(0.597678916827853, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 16.9'),
#  Text(0.6092843326885881, 0.3181818181818182, 'x[0] <= 1.061\nsquared_error = 0.006\nsamples = 5\nvalue = 16.56'),
#  Text(0.6054158607350096, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 16.7'),
#  Text(0.6131528046421664, 0.22727272727272727, 'x[2] <= 102.35\nsquared_error = 0.002\nsamples = 4\nvalue = 16.525'),
#  Text(0.6092843326885881, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 16.5'),
#  Text(0.6170212765957447, 0.13636363636363635, 'x[4] <= 210.25\nsquared_error = 0.003\nsamples = 2\nvalue = 16.55'),
#  Text(0.6131528046421664, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 16.6'),
#  Text(0.620889748549323, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.6421663442940039, 0.5909090909090909, 'x[0] <= 1.067\nsquared_error = 1.057\nsamples = 13\nvalue = 15.277'),
#  Text(0.6382978723404256, 0.5, 'x[0] <= 1.064\nsquared_error = 0.207\nsamples = 12\nvalue = 15.008'),
#  Text(0.6305609284332688, 0.4090909090909091, 'x[2] <= 103.5\nsquared_error = 0.062\nsamples = 3\nvalue = 15.667'),
#  Text(0.6266924564796905, 0.3181818181818182, 'x[0] <= 1.063\nsquared_error = 0.01\nsamples = 2\nvalue = 15.5'),
#  Text(0.6228239845261122, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.6305609284332688, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 15.4'),
#  Text(0.6344294003868471, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 16.0'),
#  Text(0.6460348162475822, 0.4090909090909091, 'x[1] <= 82.6\nsquared_error = 0.063\nsamples = 9\nvalue = 14.789'),
#  Text(0.6421663442940039, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 14.2'),
#  Text(0.6499032882011605, 0.3181818181818182, 'x[0] <= 1.065\nsquared_error = 0.022\nsamples = 8\nvalue = 14.862'),
#  Text(0.6402321083172147, 0.22727272727272727, 'x[0] <= 1.065\nsquared_error = 0.006\nsamples = 5\nvalue = 14.96'),
#  Text(0.632495164410058, 0.13636363636363635, 'x[3] <= 92.05\nsquared_error = 0.002\nsamples = 2\nvalue = 15.05'),
#  Text(0.6286266924564797, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 15.1'),
#  Text(0.6363636363636364, 0.045454545454545456, 'squared_error = -0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.6479690522243714, 0.13636363636363635, 'x[0] <= 1.065\nsquared_error = 0.0\nsamples = 3\nvalue = 14.9'),
#  Text(0.6441005802707931, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 14.9'),
#  Text(0.6518375241779497, 0.045454545454545456, 'squared_error = -0.0\nsamples = 2\nvalue = 14.9'),
#  Text(0.6595744680851063, 0.22727272727272727, 'x[0] <= 1.065\nsquared_error = 0.007\nsamples = 3\nvalue = 14.7'),
#  Text(0.655705996131528, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 14.8'),
#  Text(0.6634429400386848, 0.13636363636363635, 'x[3] <= 101.3\nsquared_error = 0.003\nsamples = 2\nvalue = 14.65'),
#  Text(0.6595744680851063, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 14.7'),
#  Text(0.6673114119922631, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 14.6'),
#  Text(0.6460348162475822, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.7156673114119922, 0.6818181818181818, 'x[0] <= 1.07\nsquared_error = 0.566\nsamples = 20\nvalue = 12.855'),
#  Text(0.6924564796905223, 0.5909090909090909, 'x[0] <= 1.068\nsquared_error = 0.144\nsamples = 10\nvalue = 13.53'),
#  Text(0.6827852998065764, 0.5, 'x[0] <= 1.068\nsquared_error = 0.031\nsamples = 7\nvalue = 13.757'),
#  Text(0.6750483558994197, 0.4090909090909091, 'x[0] <= 1.067\nsquared_error = 0.005\nsamples = 4\nvalue = 13.9'),
#  Text(0.6711798839458414, 0.3181818181818182, 'x[0] <= 1.067\nsquared_error = 0.002\nsamples = 3\nvalue = 13.933'),
#  Text(0.6673114119922631, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(0.6750483558994197, 0.22727272727272727, 'x[4] <= 171.625\nsquared_error = 0.0\nsamples = 2\nvalue = 13.9'),
#  Text(0.6711798839458414, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 13.9'),
#  Text(0.6789168278529981, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 13.9'),
#  Text(0.6789168278529981, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 13.8'),
#  Text(0.690522243713733, 0.4090909090909091, 'x[3] <= 89.5\nsquared_error = 0.002\nsamples = 3\nvalue = 13.567'),
#  Text(0.6866537717601547, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 13.5'),
#  Text(0.6943907156673114, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 13.6'),
#  Text(0.7021276595744681, 0.5, 'x[4] <= 153.875\nsquared_error = 0.007\nsamples = 3\nvalue = 13.0'),
#  Text(0.6982591876208898, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(0.7059961315280464, 0.4090909090909091, 'x[0] <= 1.069\nsquared_error = 0.002\nsamples = 2\nvalue = 12.95'),
#  Text(0.7021276595744681, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 13.0'),
#  Text(0.7098646034816247, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(0.7388781431334622, 0.5909090909090909, 'x[0] <= 1.071\nsquared_error = 0.078\nsamples = 10\nvalue = 12.18'),
#  Text(0.7292069632495164, 0.5, 'x[0] <= 1.071\nsquared_error = 0.011\nsamples = 6\nvalue = 12.383'),
#  Text(0.7214700193423598, 0.4090909090909091, 'x[1] <= 80.5\nsquared_error = 0.003\nsamples = 4\nvalue = 12.45'),
#  Text(0.7176015473887815, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 12.5'),
#  Text(0.7253384912959381, 0.3181818181818182, 'x[2] <= 97.7\nsquared_error = 0.0\nsamples = 2\nvalue = 12.4'),
#  Text(0.7214700193423598, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7292069632495164, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7369439071566731, 0.4090909090909091, 'x[3] <= 96.85\nsquared_error = 0.002\nsamples = 2\nvalue = 12.25'),
#  Text(0.7330754352030948, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 12.3'),
#  Text(0.7408123791102514, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 12.2'),
#  Text(0.7485493230174082, 0.5, 'x[4] <= 163.625\nsquared_error = 0.022\nsamples = 4\nvalue = 11.875'),
#  Text(0.7446808510638298, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 12.1'),
#  Text(0.7524177949709865, 0.4090909090909091, 'x[0] <= 1.072\nsquared_error = 0.007\nsamples = 3\nvalue = 11.8'),
#  Text(0.7485493230174082, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.7562862669245648, 0.3181818181818182, 'x[3] <= 99.3\nsquared_error = 0.002\nsamples = 2\nvalue = 11.75'),
#  Text(0.7524177949709865, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.7601547388781431, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.7'),
#  Text(0.9020793036750484, 0.7727272727272727, 'x[0] <= 1.081\nsquared_error = 8.251\nsamples = 47\nvalue = 7.957'),
#  Text(0.8351063829787234, 0.6818181818181818, 'x[0] <= 1.077\nsquared_error = 1.103\nsamples = 26\nvalue = 9.615'),
#  Text(0.7940038684719536, 0.5909090909090909, 'x[0] <= 1.074\nsquared_error = 0.244\nsamples = 12\nvalue = 10.575'),
#  Text(0.7756286266924565, 0.5, 'x[2] <= 94.2\nsquared_error = 0.078\nsamples = 5\nvalue = 11.08'),
#  Text(0.7678916827852998, 0.4090909090909091, 'x[0] <= 1.074\nsquared_error = 0.009\nsamples = 3\nvalue = 10.867'),
#  Text(0.7640232108317214, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.0'),
#  Text(0.7717601547388782, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 10.8'),
#  Text(0.7833655705996132, 0.4090909090909091, 'x[0] <= 1.073\nsquared_error = 0.01\nsamples = 2\nvalue = 11.4'),
#  Text(0.7794970986460348, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.5'),
#  Text(0.7872340425531915, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 11.3'),
#  Text(0.8123791102514507, 0.5, 'x[0] <= 1.076\nsquared_error = 0.05\nsamples = 7\nvalue = 10.214'),
#  Text(0.7988394584139265, 0.4090909090909091, 'x[0] <= 1.075\nsquared_error = 0.016\nsamples = 3\nvalue = 10.433'),
#  Text(0.7949709864603481, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 10.6'),
#  Text(0.8027079303675049, 0.3181818181818182, 'x[2] <= 99.2\nsquared_error = 0.002\nsamples = 2\nvalue = 10.35'),
#  Text(0.7988394584139265, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.3'),
#  Text(0.8065764023210832, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.8259187620889749, 0.4090909090909091, 'x[0] <= 1.076\nsquared_error = 0.012\nsamples = 4\nvalue = 10.05'),
#  Text(0.8181818181818182, 0.3181818181818182, 'x[3] <= 94.7\nsquared_error = 0.003\nsamples = 2\nvalue = 10.15'),
#  Text(0.8143133462282398, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.1'),
#  Text(0.8220502901353965, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.2'),
#  Text(0.8336557059961315, 0.3181818181818182, 'x[1] <= 85.1\nsquared_error = 0.002\nsamples = 2\nvalue = 9.95'),
#  Text(0.8297872340425532, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 9.9'),
#  Text(0.8375241779497099, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.0'),
#  Text(0.8762088974854932, 0.5909090909090909, 'x[0] <= 1.079\nsquared_error = 0.374\nsamples = 14\nvalue = 8.793'),
#  Text(0.8607350096711799, 0.5, 'x[0] <= 1.078\nsquared_error = 0.097\nsamples = 8\nvalue = 9.25'),
#  Text(0.8529980657640233, 0.4090909090909091, 'x[2] <= 96.55\nsquared_error = 0.01\nsamples = 5\nvalue = 9.48'),
#  Text(0.8491295938104448, 0.3181818181818182, 'x[2] <= 92.5\nsquared_error = 0.0\nsamples = 3\nvalue = 9.4'),
#  Text(0.8452611218568665, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 9.4'),
#  Text(0.8529980657640233, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 9.4'),
#  Text(0.8568665377176016, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 9.6'),
#  Text(0.8684719535783365, 0.4090909090909091, 'x[4] <= 173.375\nsquared_error = 0.009\nsamples = 3\nvalue = 8.867'),
#  Text(0.8646034816247582, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 8.8'),
#  Text(0.8723404255319149, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 9.0'),
#  Text(0.8916827852998066, 0.5, 'x[0] <= 1.08\nsquared_error = 0.091\nsamples = 6\nvalue = 8.183'),
#  Text(0.8839458413926499, 0.4090909090909091, 'x[2] <= 95.45\nsquared_error = 0.016\nsamples = 3\nvalue = 8.467'),
#  Text(0.8800773694390716, 0.3181818181818182, 'x[2] <= 91.55\nsquared_error = 0.003\nsamples = 2\nvalue = 8.55'),
#  Text(0.8762088974854932, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 8.6'),
#  Text(0.8839458413926499, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 8.5'),
#  Text(0.8878143133462283, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(0.8994197292069632, 0.4090909090909091, 'x[0] <= 1.081\nsquared_error = 0.007\nsamples = 3\nvalue = 7.9'),
#  Text(0.8955512572533849, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.9032882011605415, 0.3181818181818182, 'x[1] <= 82.75\nsquared_error = 0.002\nsamples = 2\nvalue = 7.85'),
#  Text(0.8994197292069632, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 7.9'),
#  Text(0.90715667311412, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 7.8'),
#  Text(0.9690522243713733, 0.6818181818181818, 'x[4] <= 207.75\nsquared_error = 9.483\nsamples = 21\nvalue = 5.905'),
#  Text(0.965183752417795, 0.5909090909090909, 'x[0] <= 1.089\nsquared_error = 3.02\nsamples = 20\nvalue = 5.33'),
#  Text(0.941972920696325, 0.5, 'x[0] <= 1.084\nsquared_error = 0.566\nsamples = 13\nvalue = 6.423'),
#  Text(0.9264990328820116, 0.4090909090909091, 'x[0] <= 1.082\nsquared_error = 0.17\nsamples = 6\nvalue = 7.1'),
#  Text(0.9187620889748549, 0.3181818181818182, 'x[1] <= 78.75\nsquared_error = 0.01\nsamples = 2\nvalue = 7.6'),
#  Text(0.9148936170212766, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 7.7'),
#  Text(0.9226305609284333, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(0.9342359767891683, 0.3181818181818182, 'x[1] <= 78.7\nsquared_error = 0.062\nsamples = 4\nvalue = 6.85'),
#  Text(0.9303675048355899, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 6.6'),
#  Text(0.9381044487427466, 0.22727272727272727, 'x[0] <= 1.083\nsquared_error = 0.0\nsamples = 2\nvalue = 7.1'),
#  Text(0.9342359767891683, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 7.1'),
#  Text(0.941972920696325, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 7.1'),
#  Text(0.9574468085106383, 0.4090909090909091, 'x[0] <= 1.086\nsquared_error = 0.177\nsamples = 7\nvalue = 5.843'),
#  Text(0.9497098646034816, 0.3181818181818182, 'x[4] <= 164.25\nsquared_error = 0.017\nsamples = 4\nvalue = 6.175'),
#  Text(0.9458413926499033, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 6.3'),
#  Text(0.9535783365570599, 0.22727272727272727, 'x[4] <= 178.625\nsquared_error = 0.002\nsamples = 2\nvalue = 6.05'),
#  Text(0.9497098646034816, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 6.1'),
#  Text(0.9574468085106383, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.965183752417795, 0.3181818181818182, 'x[0] <= 1.087\nsquared_error = 0.047\nsamples = 3\nvalue = 5.4'),
#  Text(0.9613152804642167, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 5.7'),
#  Text(0.9690522243713733, 0.22727272727272727, 'x[0] <= 1.087\nsquared_error = 0.003\nsamples = 2\nvalue = 5.25'),
#  Text(0.965183752417795, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 5.3'),
#  Text(0.9729206963249516, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 5.2'),
#  Text(0.988394584139265, 0.5, 'x[4] <= 126.625\nsquared_error = 1.237\nsamples = 7\nvalue = 3.3'),
#  Text(0.9845261121856866, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 0.7'),
#  Text(0.9922630560928434, 0.4090909090909091, 'x[0] <= 1.092\nsquared_error = 0.129\nsamples = 6\nvalue = 3.733'),
#  Text(0.988394584139265, 0.3181818181818182, 'x[0] <= 1.091\nsquared_error = 0.026\nsamples = 5\nvalue = 3.88'),
#  Text(0.9845261121856866, 0.22727272727272727, 'x[0] <= 1.09\nsquared_error = 0.007\nsamples = 3\nvalue = 4.0'),
#  Text(0.9806576402321083, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 4.1'),
#  Text(0.988394584139265, 0.13636363636363635, 'x[4] <= 131.875\nsquared_error = 0.003\nsamples = 2\nvalue = 3.95'),
#  Text(0.9845261121856866, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.9922630560928434, 0.045454545454545456, 'squared_error = -0.0\nsamples = 1\nvalue = 3.9'),
#  Text(0.9922630560928434, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 3.7'),
#  Text(0.9961315280464217, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.9729206963249516, 0.5909090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 17.4')]

# %%
path = reg.cost_complexity_pruning_path(X_train,y_train)
ccp_alpha = path.ccp_alphas

# %%
alphalist = []
for i in range(len(ccp_alpha)):
  reg = DecisionTreeRegressor(ccp_alpha=ccp_alpha[i])
  reg.fit(X_train,y_train)
  alphalist.append(reg)

# %%
trainscore = [alphalist[i].score(X_train,y_train) for i in range(len(alphalist))]

testscore = [alphalist[i].score(X_test,y_test) for i in range(len(alphalist))]

plt.xlabel('alpha')
plt.ylabel('accuracy')
plt.plot(ccp_alpha, trainscore, marker = 'o', label = 'training', color = 'magenta', drawstyle = 'steps-post')
plt.plot(ccp_alpha, testscore, marker = '+', label = 'testing', color = 'red', drawstyle = 'steps-post')
plt.legend()
plt.show()

# %%
clf = DecisionTreeRegressor(ccp_alpha=1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(f'Decision Tree Normal Approach: {metrics.r2_score(y_test,y_pred)}')

rf = RandomForestRegressor(n_estimators=1000,ccp_alpha=1)
rf.fit(X_train,y_train)
y_pred_rf = rf.predict(X_test)
print(f'Random Forest Normal Approach: {metrics.r2_score(y_test,y_pred_rf)}')
# Out:
# Decision Tree Normal Approach: 0.8831872268905295
# Random Forest Normal Approach: 0.9301887432945478

# %% [markdown]
# **Hyperparamter Tuning**

# %%
import numpy as np

# %%
params = {
    'RandomForest': {
        'model': RandomForestRegressor(),
        'params': {
            'n_estimators': [int(x) for x in np.linspace(start=1, stop=1200, num=10)],
            'criterion': ['poisson', 'absolute_error', 'friedman_mse', 'squared_error'],
            'max_depth': [int(x) for x in np.linspace(start=1, stop=30, num=5)],
            'min_samples_split': [2, 5, 10, 12],
            'min_samples_leaf': [2, 5, 10, 12],
            'max_features': ['auto', 'sqrt'],
            'ccp_alpha': [1, 2, 2.5, 3, 3.5, 4, 5],
        }
    },
    'D-tree': {
        'model': DecisionTreeRegressor(),
        'params': {
            'criterion': ['poisson', 'absolute_error', 'friedman_mse', 'squared_error'],
            'splitter': ['best', 'random'],
            'min_samples_split': [1, 2, 5, 10, 12],
            'min_samples_leaf': [1, 2, 5, 10, 12],
            'max_features': ['auto', 'sqrt'],
            'ccp_alpha': [1, 2, 2.5, 3, 3.5, 4, 5],
        }
    },
    'SVM': {
        'model': SVR(),
        'params': {
            'C': [0.25, 0.50, 0.75, 1.0],
            'tol': [1e-10, 1e-5, 1e-4, 0.025, 0.50, 0.75],
            'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
            'max_iter': [int(x) for x in np.linspace(start=1, stop=250, num=10)],
        }
    }
}

# %%
scores = []
for modelname, mp in params.items():
    clf = RandomizedSearchCV(mp['model'], param_distributions=mp['params'], cv=5, n_jobs=-1, n_iter=10,
                             scoring='neg_mean_squared_error')
    clf.fit(X_train, y_train)
    scores.append({
        'model_name': modelname,
        'best_score': clf.best_score_,
        'best_estimator': clf.best_estimator_
    })
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=167).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
scoresdf = pd.DataFrame(scores,columns=['model_name','best_score','best_estimator'])
scoresdf
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest   -5.386674  (DecisionTreeRegressor(ccp_alpha=2, max_depth=...
# 1        D-tree   -8.025072  DecisionTreeRegressor(ccp_alpha=2.5, max_featu...
# 2           SVM  -50.419728  SVR(C=0.25, kernel='linear', max_iter=167, tol...

# %%
scores[0]['best_estimator']
# Out:
# RandomForestRegressor(ccp_alpha=2, max_depth=15, max_features='auto',
#                       min_samples_leaf=12, min_samples_split=10,
#                       n_estimators=267)

# %%
rf = scores[0]['best_estimator']
rf.fit(X_train,y_train)

y_pred = rf.predict(X_test)

print(metrics.r2_score(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# 0.8873969367010702

# %%
totrainlist = np.array(totrain)
predicted = []
for i in range(len(totrainlist)):
  predicted.append(rf.predict([totrainlist[i]]))

totrain['Actual Result'] = test
totrain['Predicted Result'] = np.array(predicted)
totrain
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# <ipython-input-58-d6b955a17d7e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['Actual Result'] = test
# <ipython-input-58-d6b955a17d7e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['Predicted Result'] = np.array(predicted)
#      Density  Abdomen  Chest    Hip  Weight  Actual Result  Predicted Result
# 0     1.0708     85.2   93.1   94.5  154.25           12.3         13.677964
# 1     1.0853     83.0   93.6   98.7  173.25            6.1          8.166018
# 2     1.0414     87.9   95.8   99.2  154.00           25.3         23.577467
# 3     1.0751     86.4  101.8  101.2  184.75           10.4          8.212337
# 4     1.0340    100.0   97.3  101.9  184.25           28.7         30.584249
# ..       ...      ...    ...    ...     ...            ...               ...
# 247   1.0736     83.6   89.2   88.8  134.25           11.0          8.568613
# 248   1.0236    105.0  108.5  104.5  201.00           33.6         32.598213
# 249   1.0328    111.5  111.1  101.7  186.75           29.3         31.573623
# 250   1.0399    101.3  108.3   97.8  190.75           26.0         23.736051
# 251   1.0271    108.5  112.4  107.1  207.50           31.9         32.598213
#
# [252 rows x 7 columns]

# %%
sn.distplot(totrain['Actual Result'],label='Actual Result', hist=False, color='magenta')
sn.distplot(totrain['Predicted Result'], label = 'Predicted Result', hist=False, color='red')
plt.legend()
plt.plot()
# Out:
# <ipython-input-59-011923fee168>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(totrain['Actual Result'],label='Actual Result', hist=False, color='magenta')
# <ipython-input-59-011923fee168>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(totrain['Predicted Result'], label = 'Predicted Result', hist=False, color='red')
# []

# %%
import pickle

file = open('bodyfatmodel1.pkl','wb')
pickle.dump(rf,file)
file.close()
